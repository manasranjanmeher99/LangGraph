# %%
#pip install -qU "langchain[google-genai]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Set the API key (Note: avoid hardcoding sensitive keys in production)
os.environ["GOOGLE_API_KEY"] = ""

# Import the correct class for using Gemini models via LangChain
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the model (use "gemini-1.5-flash" or "gemini-1.5-pro" – not "2.0-flash" as it doesn't exist)
model = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")

# Test the model
response = model.invoke("What's the capital of France?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'ErABCq0BARFNMg/YmVlZqfk7i3nxY6jwdlugrWNhf2v1hPpNcOKCpHZE26QkjEv48TwTOLrT0I3EcBmNheTdgJug6QvChN9sGpvthqVw2pxIX/mksUizzKaxLUZ2w8k9yYuVPR0nQguJUk/GXPN1APAN9h6SYmla/6h8Z6iWDSkw2RkuAv6JgmbF6wjznfJTcv5Cl1pCfomGtISffwNVXunA4B63fs+AfpV44Rm4ayJebF0='}}]

# %%
model.invoke("About Generative AI and Agentic AI")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The transition from **Generative AI** to **Agentic AI** represents the next major frontier in artificial intelligence. While they are closely related, they represent a shift from AI as a **communicator** to AI as a **worker.**\n\nHere is a breakdown of what they are, how they differ, and why the shift matters.\n\n---\n\n### 1. Generative AI (The Foundation)\nGenerative AI refers to models that can create new content—text, images, code, or audio—based on the patterns they learned from massive datasets during training.\n\n*   **How it works:** It is primarily **probabilistic**. When you give it a prompt, it predicts the next most likely token (word or pixel) to produce a response.\n*   **The User Experience:** It is **Reactive.** You give it a prompt, and it gives you an output. If you want it to change something, you must provide a new prompt.\n*   **Examples:** ChatGPT (as a chatbot), Claude, Midjourney, DALL-E.\n*   **Limitation:** It doesn\'t "do" anything outside of its chat window. It can write a workout plan, but it cannot book the gym for you.\n\n---\n\n### 2. Agentic AI (The Evolution)\nAgentic AI refers to systems that use Generative AI as their "brain" but are equipped with **agency.** They are designed to achieve a specific goal by reasoning, planning, and using tools autonomously.\n\n*   **How it works:** Instead of just responding to a prompt, an AI Agent breaks a complex goal into a series of steps. It can interact with the real world (via APIs, web browsers, or software) to complete those steps.\n*   **The User Experience:** It is **Proactive.** You give it a goal (e.g., "Research this company, find the CEO\'s email, and draft a personalized pitch based on their last quarterly report"), and it executes the workflow without you needing to guide every step.\n*   **Core Components:**\n    *   **Reasoning/Planning:** The ability to think, "What should I do first?"\n    *   **Tool Use:** The ability to use a calculator, search the web, or run code.\n    *   **Memory:** Remembering what worked and what didn\'t in previous steps.\n    *   **Self-Correction:** If it hits a 404 error on a website, it doesn\'t stop; it tries a different link.\n\n---\n\n### 3. Key Differences at a Glance\n\n| Feature | Generative AI | Agentic AI |\n| :--- | :--- | :--- |\n| **Primary Goal** | Creating content / Information retrieval | Achieving a goal / Completing a task |\n| **Human Input** | Requires constant prompting (Step-by-step) | Requires a high-level objective (One-time) |\n| **Output** | Text, images, or code | Actions, workflows, and finished projects |\n| **Autonomy** | Low (waits for the next command) | High (operates in a loop until done) |\n| **Analogy** | A very smart **Encyclopedia** | A very capable **Intern** |\n\n---\n\n### 4. How an Agentic Workflow Looks\nIf you ask a standard **Generative AI** to "Write a research paper," it will write what it knows at that moment.\n\nIf you ask an **Agentic AI** to "Write a research paper," it follows a loop:\n1.  **Plan:** "I need to find recent sources on this topic."\n2.  **Act:** Searches Google Scholar and downloads three PDFs.\n3.  **Read/Analyze:** Summarizes the PDFs and checks for contradictions.\n4.  **Refine:** "One source is outdated. I will search for a 2024 version."\n5.  **Produce:** Writes the paper with citations and saves it to your Google Drive.\n\n---\n\n### 5. Why the Shift Matters\nThe move toward Agentic AI is turning AI into a productivity multiplier rather than just a writing assistant.\n\n*   **In Business:** Instead of a human manually moving data from an email to a CRM, an Agentic AI can monitor the inbox, extract data, update the CRM, and send a follow-up email autonomously.\n*   **In Software:** "Devin" (the first AI software engineer) is an example of Agentic AI. It doesn\'t just suggest code; it writes, tests, and builds entire applications.\n*   **In Personal Life:** Future agents will act as personal assis ...
